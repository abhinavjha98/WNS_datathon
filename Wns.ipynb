# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
traind = pd.read_csv("/content/drive/My Drive/WNS/train_NA17Sgz/train.csv")
item = pd.read_csv("/content/drive/My Drive/WNS/train_NA17Sgz/item_data.csv")
log =  pd.read_csv("/content/drive/My Drive/WNS/train_NA17Sgz/view_log.csv")

# %%
it_log = pd.merge(log,item,on='item_id')

# %%
log.shape
# Out:
# (3118622, 5)

# %%
it_log.shape
# Out:
# (3116840, 10)

# %%
it_log.head()
# Out:
#            server_time device_type  ...  category_3  product_type
# 0  2018-10-15 08:58:00     android  ...         253          3184
# 1  2018-10-15 09:36:00     android  ...         253          3184
# 2  2018-10-15 10:59:00     android  ...         253          3184
# 3  2018-10-15 11:31:00     android  ...         253          3184
# 4  2018-10-15 12:03:00     android  ...         253          3184
#
# [5 rows x 10 columns]

# %%
it_log['server_time'] = pd.to_datetime(it_log['server_time'],format="%Y-%m-%d %H:%M:%S")
it_log.head()
# Out:
#           server_time device_type  ...  category_3  product_type
# 0 2018-10-15 08:58:00     android  ...         253          3184
# 1 2018-10-15 09:36:00     android  ...         253          3184
# 2 2018-10-15 10:59:00     android  ...         253          3184
# 3 2018-10-15 11:31:00     android  ...         253          3184
# 4 2018-10-15 12:03:00     android  ...         253          3184
#
# [5 rows x 10 columns]

# %%
it_log.dtypes
# Out:
# server_time     datetime64[ns]
# device_type             object
# session_id               int64
# user_id                  int64
# item_id                  int64
# item_price               int64
# category_1               int64
# category_2               int64
# category_3               int64
# product_type             int64
# dtype: object

# %%
traind.head()
# Out:
#                       impression_id      impression_time  ...  is_4G  is_click
# 0  c4ca4238a0b923820dcc509a6f75849b  2018-11-15 00:00:00  ...      0         0
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  2018-11-15 00:01:00  ...      1         1
# 2  70efdf2ec9b086079795c442636b55fb  2018-11-15 00:02:00  ...      1         0
# 3  8e296a067a37563370ded05f5a3bf3ec  2018-11-15 00:02:00  ...      1         0
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  2018-11-15 00:02:00  ...      0         0
#
# [5 rows x 7 columns]

# %%
traind.dtypes
# Out:
# impression_id      object
# impression_time    object
# user_id             int64
# app_code            int64
# os_version         object
# is_4G               int64
# is_click            int64
# dtype: object

# %%
traind['impression_time'] = pd.to_datetime(traind['impression_time'],format="%Y-%m-%d %H:%M:%S")
traind.head()
# Out:
#                       impression_id     impression_time  ...  is_4G  is_click
# 0  c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00  ...      0         0
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00  ...      1         1
# 2  70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00  ...      1         0
# 3  8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00  ...      1         0
# 4  182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00  ...      0         0
#
# [5 rows x 7 columns]

# %%
traind['itemp']=0
traind['categ1']=0
traind['categ2']=0
traind['categ3']=0
traind['prod']=0
traind.head()
# Out:
#                       impression_id     impression_time  ...  categ3  prod
# 0  c4ca4238a0b923820dcc509a6f75849b 2018-11-15 00:00:00  ...       0     0
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26 2018-11-15 00:01:00  ...       0     0
# 2  70efdf2ec9b086079795c442636b55fb 2018-11-15 00:02:00  ...       0     0
# 3  8e296a067a37563370ded05f5a3bf3ec 2018-11-15 00:02:00  ...       0     0
# 4  182be0c5cdcd5072bb1864cdee4d3d6e 2018-11-15 00:02:00  ...       0     0
#
# [5 rows x 12 columns]

# %%
for i in traind.index:
  itemp,categ1,categ2,prod,categ3 = 0,0,0,0,0
  user_id = traind.get_value(i,'user_id')
  date = traind.get_value(i,'impression_time')
  chku = it_log.user_id == user_id
  uhm1 = it_log[chku]
  for j in uhm1.index:
    date1 = uhm1.get_value(j,'server_time')
    if date>date1:
      i+=1
      itemp += uhm1.get_value(j,'item_price')
      categ1 += uhm1.get_value(j,'category_1')
      categ2 += uhm1.get_value(j,'category_2')
      categ3 += uhm1.get_value(j,'category_3')
      prod += uhm1.get_value(j,'product_type')
  traind.set_value(i,'itemp',itemp)
  traind.set_value(i,'categ1',categ1)
  traind.set_value(i,'categ2',categ2)
  traind.set_value(i,'categ3',categ3)
  traind.set_value(i,'prod',prod)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
traind.sample(10)
# Out:
#                            impression_id     impression_time  ...  categ3    prod
# 124828  2eb99d6ec62a20824d1a6d63c32ad0a0 2018-12-01 18:30:00  ...     100    5168
# 3134    05edf455cb266ccb3ea3ac2715f87326 2018-11-15 09:39:00  ...   12826  410068
# 228924  bf51efa7b18150e74675ded1c8a81932 2018-12-11 07:10:00  ...     151    8251
# 63753   42131efc252155c98bb67daf63e35faf 2018-11-26 16:14:00  ...    4427   83645
# 186247  a3d66b960ccbd5bac6179ff3cfe2ab08 2018-12-07 14:37:00  ...    1223   45057
# 203576  7ce8bfcbb89e05e098df343b8cda80c6 2018-12-09 08:47:00  ...    1333   39617
# 118722  e5f2dcc9f2a0708b2e2e5b608a589cef 2018-11-30 22:42:00  ...   17856  458298
# 127391  c6f123d4b13a502ae79f60b86c8d09ed 2018-12-01 14:02:00  ...   11565  309779
# 27012   23f10867ae6acbd27fdbaa5e92065732 2018-11-20 15:57:00  ...     203    2270
# 207847  5186af5307a49986c238a770492e91fe 2018-12-11 13:04:00  ...    9948  375077
#
# [10 rows x 12 columns]

# %%
it_log.sample(5)
# Out:
#                 server_time device_type  ...  category_3  product_type
# 1206082 2018-12-02 22:07:00     android  ...         275          6439
# 1354785 2018-12-09 19:03:00     android  ...         154          7461
# 415645  2018-11-16 18:22:00     android  ...          96          8690
# 1967866 2018-10-23 18:19:00     android  ...          62          3928
# 13706   2018-12-07 09:36:00     android  ...         283           908
#
# [5 rows x 10 columns]

# %%
traind = pd.get_dummies(traind,columns=['os_version'])
traind.head()
# Out:
#                       impression_id  ... os_version_old
# 0  c4ca4238a0b923820dcc509a6f75849b  ...              1
# 1  45c48cce2e2d7fbdea1afc51c7c6ad26  ...              0
# 2  70efdf2ec9b086079795c442636b55fb  ...              0
# 3  8e296a067a37563370ded05f5a3bf3ec  ...              0
# 4  182be0c5cdcd5072bb1864cdee4d3d6e  ...              0
#
# [5 rows x 14 columns]

# %%
train = traind.drop(['user_id','impression_time'],axis=1)

# %%
train.sample(10)
# Out:
#                            impression_id  ...  os_version_old
# 150431  cfa1e2342789a1970ab22857fd58f4b8  ...               0
# 196460  3e66b32d4667162866b46d161b7597ca  ...               0
# 142975  6b9b7e812f46605b242714b8a8b55b2c  ...               1
# 125568  51325bbe834e59df8c8d369877222202  ...               1
# 5109    8e488a9d7efff8b0825b4f7e581fea4e  ...               0
# 102571  dda237ebe1964dc23810f077f592635f  ...               1
# 45701   48b508b64892bdf1d3a44e6de12e146a  ...               1
# 61306   5f29cff1a40a80d9b1b1f0c32176125f  ...               1
# 102410  e2cf0bec385d70f19c0b5ed1580b27fa  ...               0
# 216148  e74c12cbf2438ad6fede9e8670a138fe  ...               1
#
# [10 rows x 12 columns]

# %%
from sklearn import preprocessing
train[['app_code']] = \
                 preprocessing.scale(train[['app_code']])

# %%
train[['itemp']] = \
                 preprocessing.scale(train[['itemp']])
train[['categ1']] = \
                 preprocessing.scale(train[['categ1']])
train[['categ2']] = \
                 preprocessing.scale(train[['categ2']])
train[['categ3']] = \
                 preprocessing.scale(train[['categ3']])
train[['prod']] = \
                 preprocessing.scale(train[['prod']])

# %%
train.dtypes
# Out:
# impression_id              object
# app_code                    int64
# is_4G                       int64
# is_click                    int64
# itemp                       int64
# categ1                      int64
# categ2                      int64
# categ3                      int64
# prod                        int64
# os_version_intermediate     uint8
# os_version_latest           uint8
# os_version_old              uint8
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import SGDClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
result_dict = {}

# %%
def summarize_classification(y_test, y_pred):
    
    acc = accuracy_score(y_test, y_pred, normalize=True)
    num_acc = accuracy_score(y_test, y_pred, normalize=False)

    prec = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    
    return {'accuracy': acc, 
            'precision': prec,
            'recall':recall, 
            'accuracy_count':num_acc}

# %%
def build_model(classifier_fn,                
                name_of_y_col, 
                names_of_x_cols, 
                dataset, 
                test_frac=0.2):
    
    X = dataset[names_of_x_cols]
    Y = dataset[name_of_y_col]

    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=test_frac)
       
    model = classifier_fn(x_train, y_train)
    
    y_pred = model.predict(x_test)

    y_pred_train = model.predict(x_train)
    
    train_summary = summarize_classification(y_train, y_pred_train)
    test_summary = summarize_classification(y_test, y_pred)
    
    pred_results = pd.DataFrame({'y_test': y_test,
                                 'y_pred': y_pred})
    
    print(pred_results.sample(10))
    
    model_crosstab = pd.crosstab(pred_results.y_pred, pred_results.y_test)
    
    return {'training': train_summary, 
            'test': test_summary,
            'confusion_matrix': model_crosstab}

# %%
def compare_results():
    for key in result_dict:
        print('Classification: ', key)

        print()
        print('Training data')
        for score in result_dict[key]['training']:
            print(score, result_dict[key]['training'][score])

        print()
        print('Test data')
        for score in result_dict[key]['test']:
            print(score, result_dict[key]['test'][score])
       
        print()

# %%
def sgd_fn(x_train, y_train, max_iter=1000, tol=1e-3):
    
    model = SGDClassifier(max_iter=max_iter, tol=tol)
    model.fit(x_train, y_train)
     
    return model

# %%
def decision_tree_fn(x_train, y_train, max_depth=40, max_features=None): 
    
    model = DecisionTreeClassifier(max_depth=max_depth, max_features=max_features)
    model.fit(x_train, y_train)
    
    return model

# %%
def naive_bayes_fn(x_train,y_train, priors=None):
    
    model = GaussianNB(priors=priors)
    model.fit(x_train, y_train)
    
    return model

# %%
train.columns
# Out:
# Index(['impression_id', 'app_code', 'is_4G', 'is_click', 'itemp', 'categ1',
#        'categ2', 'categ3', 'prod', 'os_version_intermediate',
#        'os_version_latest', 'os_version_old'],
#       dtype='object')

# %%
result_dict['survived ~ dt3'] = build_model(naive_bayes_fn,
                                              'is_click',
                                               [ 'app_code', 'is_4G', 'itemp', 'categ1',
       'categ2', 'categ3', 'os_version_intermediate',
       'os_version_latest', 'os_version_old','prod'],
                                               train)

compare_results()
# Out:
#         y_test  y_pred
# 74721        0       0
# 168015       0       0
# 192244       0       0
# 138946       0       0
# 129306       0       0
# 56043        0       0
# 225193       0       0
# 47906        0       0
# 236681       0       0
# 139111       1       0
# Classification:  survived ~ dt
#
# Training data
# accuracy 0.9543366984591266
# precision 0.0
# recall 0.0
# accuracy_count 181407
#
# Test data
# accuracy 0.9540844240562266
# precision 0.0
# recall 0.0
# accuracy_count 45340
#
# Classification:  survived ~ dt1
#
# Training data
# accuracy 0.9547996443733658
# precision 0.0
# recall 0.0
# accuracy_count 181495
#
# Test data
# accuracy 0.9522326501409873
# precision 0.0
# recall 0.0
# accuracy_count 45252
#
# Classification:  survived ~ dt2
#
# Training data
# accuracy 0.9544839994318391
# precision 0.0
# recall 0.0
# accuracy_count 181435
#
# Test data
# accuracy 0.9534952232650141
# precision 0.0
# recall 0.0
# accuracy_count 45312
#
# Classification:  survived ~ dt3
#
# Training data
# accuracy 0.9124927007107272
# precision 0.0703755514903691
# recall 0.07561567811307665
# accuracy_count 173453
#
# Test data
# accuracy 0.9109254660999117
# precision 0.06689536878216124
# recall 0.07049254405784004
# accuracy_count 43289

# %%
def logistic_fn(x_train, y_train):
    
    model = LogisticRegression(solver='liblinear')
    model.fit(x_train, y_train)
    
    return model

# %%
from sklearn.model_selection import train_test_split

X = train.drop(['is_click','impression_id'], axis=1)
Y = train['is_click']



x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
#x_test = a2.drop('is_goal_x',axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train,y_train)

y_pred=clf.predict(new_x)

# %%
test = pd.read_csv('/content/drive/My Drive/WNS/test_aq1FGdB/test.csv')
test.head()
# Out:
#                       impression_id      impression_time  ...  os_version  is_4G
# 0  a9e7126a585a69a32bc7414e9d0c0ada  2018-12-13 07:44:00  ...      latest      1
# 1  caac14a5bf2ba283db7708bb34855760  2018-12-13 07:45:00  ...      latest      0
# 2  13f10ba306a19ce7bec2f3cae507b698  2018-12-13 07:46:00  ...      latest      1
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  2018-12-13 07:47:00  ...      latest      1
# 4  bf5a572cca75f5fc67f4b14e58b11d70  2018-12-13 07:48:00  ...      latest      1
#
# [5 rows x 6 columns]

# %%
itemm = pd.read_csv("/content/drive/My Drive/WNS/train_NA17Sgz/item_data.csv")
logg =  pd.read_csv("/content/drive/My Drive/WNS/train_NA17Sgz/view_log.csv")

# %%
it_logg = pd.merge(log,item,on='item_id')

# %%
it_logg['server_time'] = pd.to_datetime(it_logg['server_time'],format="%Y-%m-%d %H:%M:%S")
it_logg.head()
# Out:
#           server_time device_type  ...  category_3  product_type
# 0 2018-10-15 08:58:00     android  ...         253          3184
# 1 2018-10-15 09:36:00     android  ...         253          3184
# 2 2018-10-15 10:59:00     android  ...         253          3184
# 3 2018-10-15 11:31:00     android  ...         253          3184
# 4 2018-10-15 12:03:00     android  ...         253          3184
#
# [5 rows x 10 columns]

# %%
test['impression_time'] = pd.to_datetime(test['impression_time'],format="%Y-%m-%d %H:%M:%S")
test.head()
# Out:
#                       impression_id     impression_time  ...  os_version  is_4G
# 0  a9e7126a585a69a32bc7414e9d0c0ada 2018-12-13 07:44:00  ...      latest      1
# 1  caac14a5bf2ba283db7708bb34855760 2018-12-13 07:45:00  ...      latest      0
# 2  13f10ba306a19ce7bec2f3cae507b698 2018-12-13 07:46:00  ...      latest      1
# 3  39c4b4dc0e9701b55a0a4f072008fb3f 2018-12-13 07:47:00  ...      latest      1
# 4  bf5a572cca75f5fc67f4b14e58b11d70 2018-12-13 07:48:00  ...      latest      1
#
# [5 rows x 6 columns]

# %%
test['itemp']=0
test['categ1']=0
test['categ2']=0
test['categ3']=0
test['prod']=0
test.head()
# Out:
#                       impression_id     impression_time  ...  categ3  prod
# 0  a9e7126a585a69a32bc7414e9d0c0ada 2018-12-13 07:44:00  ...       0     0
# 1  caac14a5bf2ba283db7708bb34855760 2018-12-13 07:45:00  ...       0     0
# 2  13f10ba306a19ce7bec2f3cae507b698 2018-12-13 07:46:00  ...       0     0
# 3  39c4b4dc0e9701b55a0a4f072008fb3f 2018-12-13 07:47:00  ...       0     0
# 4  bf5a572cca75f5fc67f4b14e58b11d70 2018-12-13 07:48:00  ...       0     0
#
# [5 rows x 11 columns]

# %%
for i in test.index:
  itemp,categ1,categ2,prod,categ3 = 0,0,0,0,0
  user_id = test.get_value(i,'user_id')
  date = test.get_value(i,'impression_time')
  chku = it_logg.user_id == user_id
  uhm1 = it_logg[chku]
  for j in uhm1.index:
    date1 = uhm1.get_value(j,'server_time')
    if date>date1:
      itemp += uhm1.get_value(j,'item_price')
      categ1 += uhm1.get_value(j,'category_1')
      categ2 += uhm1.get_value(j,'category_2')
      categ3 += uhm1.get_value(j,'category_3')
      prod += uhm1.get_value(j,'product_type')
  test.set_value(i,'itemp',itemp)
  test.set_value(i,'categ1',categ1)
  test.set_value(i,'categ2',categ2)
  test.set_value(i,'categ3',categ3)
  test.set_value(i,'prod',prod)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: FutureWarning: get_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
test = pd.get_dummies(test,columns=['os_version'])
test.head()
# Out:
#                       impression_id  ... os_version_old
# 0  a9e7126a585a69a32bc7414e9d0c0ada  ...              0
# 1  caac14a5bf2ba283db7708bb34855760  ...              0
# 2  13f10ba306a19ce7bec2f3cae507b698  ...              0
# 3  39c4b4dc0e9701b55a0a4f072008fb3f  ...              0
# 4  bf5a572cca75f5fc67f4b14e58b11d70  ...              0
#
# [5 rows x 13 columns]

# %%
test1 = test.drop(['user_id','impression_time'],axis=1)

# %%
from sklearn import preprocessing
test1[['app_code']] = \
                 preprocessing.scale(test1[['app_code']])
test1[['itemp']] = \
                 preprocessing.scale(test1[['itemp']])
test1[['categ1']] = \
                 preprocessing.scale(test1[['categ1']])
test1[['categ2']] = \
                 preprocessing.scale(test1[['categ2']])
test1[['categ3']] = \
                 preprocessing.scale(test1[['categ3']])
test1[['prod']] = \
                 preprocessing.scale(test1[['prod']])

# %%
aa = answer_model(naive_bayes_fn,
                                              'is_click',
                                               [ 'app_code', 'is_4G', 'itemp', 'categ1',
       'categ2', 'categ3', 'os_version_intermediate',
       'os_version_latest', 'os_version_old','prod'],
                                               train,test1)

# %%
def answer_model(classifier_fn,                
                name_of_y_col, 
                names_of_x_cols, 
                dataset,
                test,
                test_frac=0):
    
    X = dataset[names_of_x_cols]
    Y = dataset[name_of_y_col]
    x_test = test[names_of_x_cols]   
    model = classifier_fn(X,Y)
    
    y_pred = model.predict(x_test)
   
    
    return y_pred

# %%
a1['is_click'] = pd.DataFrame(aa)
a2 = a1.drop(0,axis=1)

# %%
a2.head()
# Out:
#    is_click
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
testfinal = test1['impression_id']
testfinal = pd.DataFrame(testfinal)

# %%
tf =testfinal.join(a2)

# %%
tf.sample(10)
# Out:
#                           impression_id  is_click
# 49494  855a4883d010ea2d04ff20bbca483044         0
# 72296  3b4cc26802cd1b5a28217bc17331b6ee         0
# 7741   c6436428f58f509e60c5ba15588525aa         0
# 51347  1e5efa50a54f634c3e7a085a1d63e313         0
# 45630  4847ea7a216a4e59eac8f6b5d9dbc87f         0
# 89426  dd0d472a17241807a1199b896342b641         1
# 79937  add4d01f287c38c8b415dd82b42438e8         0
# 90481  ad5130e786d13531cc0f2cde32dacd0f         0
# 12569  36bcbc3dc2e127f0355bb635dd6c0b18         0
# 56260  396b42451f1499581b6b6ec9cb1a47d6         0

# %%
tf.to_csv("Final.csv",index=False)
